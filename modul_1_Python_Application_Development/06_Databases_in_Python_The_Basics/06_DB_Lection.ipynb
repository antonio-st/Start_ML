# %% [markdown]
# # Базы данных
# `СУБД `- это целый комплекс из программ, который решает несколько задач:
#
# 1. **Как хранить данные.** СУБД решает, в каком формате будут храниться данные на диске и как их читать. Также СУБД может "размазывать" свои данные на несколько машин, чтобы увеличить суммарную емкость.
# 2. **Как получать данные.** Чаще всего используется единый язык для доступа к данным (он, кстати, называется _SQL_). Язык этот работает как конструктор, из которого вы можете собрать запрос к данным любой сложности.
# 3. **Как обеспечивать контроль доступа.** СУБД часто имеет поддержку пользователей (например, "дядя Петя" с правами "только чтение" и "админ Степан" с полным доступом на запись).
# 4. **Как восстанавливаться после сбоев, как делать резервные копии и как следить за изменениями.**

# %% [markdown]
# ## Основы SQL
#
# `SQL (Structured Query Language — Структурированный Язык Запросов)` —  это декларативный язык программирования, который используется в качестве эффективного способа управления данными — их извлечения, поиска, модификации и удаления из баз данных.
#
# `Главное преимущество использования SQL` - высокая скорость обработки больших данных. Когда у нас действительно большие данные, то лучше их сначала подготовить их через SQL и потом только выгружать для обработки в python/pandas.
#
# Для выполнения различных действий внутри СУБД используются операторы SQL.
#
# `Оператор` – это зарезервированное слово, или символ, который используется в SQL выражениях.
#
# SQL содержит 4 основные группы операторов:
#
# - Операторы описания данных (DDL - Data Definition Language ): CREATE, DROP, ALTER и др.
# - Операторы манипуляции данными (DML - Data Manipulation Language): SELECT, INSERT, DELETE, UPDATE и др.
# - Операторы контроля баз данных (DCL – Data Control Language): GRANT / REVOKE, LOCK / UNLOCK , SET LOCK MODE).
# - Операторы для управления транзакциями (TCL – Transaction Control Language): BEGIN TRANSACTION, COMMIT TRANSACTION и др.

# %%
# SELECT— предназначен для извлечения строк данных из одной или нескольких таблиц, используется совместно с оператором FROM:
# 
SELECT * 
FROM members;

# %%
# WHERE — необязательный элемент запроса, который используется, когда нужно отфильтровать данные по нужному условию:
SELECT *
FROM members
WHERE surname = 'Smith' OR firstname = 'David';

# %%
# логические операторы
# AND ("и", логическое умножение), OR ("или", логическая сумма), NOT("не", отрицание).
# численные преобразования с помощью функций SUM(сумма), SQRT(извлечение корня), ROUND (округление), ABS (модуль числа) и других
# Также можно делать проверки на принадлежность заданному множеству значений с помощью оператора IN или NOT IN (исключение)
# через LIMIT можно задать количество строк для вывода

SELECT "name" FROM facilities 
WHERE membercost IN (0, 5, 10)
LIMIT 10;

# %% [markdown]
# ## > GROUP BY и ORDER BY
#
# `GROUP BY` — позволяет группировать результаты при выборке из базы данных (аналог агрегации в python):

# %%
SELECT surname, COUNT(surname) 
FROM members 
WHERE recommendedby IS NOT NULL  # проверка на прочерк, как в Python
GROUP BY surname;

# %% [markdown]
# Ещё одной важной особенностью языка SQL является `последовательность выполнения запросов. `
#
# Так, оператор `GROUP BY может` быть использован только `после WHERE`, а не наоборот.
#
# Если нам нужно применить фильтр по уже сгруппированным данным, `применяется оператор HAVING`.
#
# Например, если нам нужно отфильтровать фамилии, которые встречаются более одного раза, то сначала необходимо сгруппировать данные по фамилии, а после применить фильтр:

# %%
SELECT surname, COUNT(surname) 
FROM members
WHERE recommended by IS NOT NULL
GROUP BY surname
HAVING COUNT(surname) > 1; # вот наша фильтрация на агрегат

# %% [markdown]
# ## Агрегатные функции SQL
#
# Также как и в python, при формировании групп нужно указать, какое значение мы хотим получить:
#
# SQL поддерживает следующие агрегатные функции:
#
# `MIN / MAX` - узнать минимальное/максимальное значение по группе
#
# `SUM` - сумировать все значения в группе
#
# `AVG` - найти среднее значение по группе
#
# `COUNT` - посчитать количество элементов группе
#
# Важно отметить, что в отличии от python, в SQL агрегатные функции указываются перед группировкой, сразу после SELECT.
#
# - Агрегатные функции `могут использоваться и без GROUP BY`,  но тогда `запрос SELECT не должен содержать простых столбцов` (кроме как столбцов, служащих аргументами агрегатной функции).
#
# - Результатом вычислений любой агрегатной функции является константное значение, отображаемое в отдельном столбце результата.
#
# Аргументу агрегатной функции может предшествовать одно из двух возможных ключевых слов:
#
# `ALL` -  вычисления выполняются над всеми значениями столбца (значение по умолчанию, указывать не обязательно).
#
# `DISTINCT` - отбирает только уникальные значения столбца.

# %%
SELECT surname, 
       COUNT(DISTINCT surname)         # подсчитает число уникальных фамилий в столбце
FROM members;

# %% [markdown]
# Оператор `AS` используется для переименования результирующих столбцов при выборке элементов, например:

# %%
SELECT COUNT('surname') AS "total_members" --выведет количество участников в колонку с названием total_members
FROM members;

# %% [markdown]
# ## Сортировка в SQL
#
# `ORDER BY` — позволяет сортировать значения при выводе таблицы.
#
# По умолчанию сортировка происходит по возрастанию (ASC). Для того, чтобы упорядочить значения от большего к меньшему, нужно добавить DESC (англ. descending — убывающий):

# %%
SELECT * 
FROM bookings
ORDER BY starttime DESC;

# %% [markdown]
# ### Структура sql-запроса
#
# ```sql
# SELECT   --столбцы или * для выбора всех столбцов; обязательный запрос
# FROM     --таблица; обязательный запрос
# WHERE    -- условие/фильтрация; необязательный запрос
# GROUP BY --столбец, по которому хотим сгруппировать данные; необязательный запрос
# HAVING   --условие/фильтрация на уровне сгруппированных данных; необязательно
# ORDER BY --столбец, по которому хотим отсортировать вывод; необязательно
# ```

# %% [markdown]
# ## > Диаграмма отношений и транзакции
# В общем виде любая СУБД состоит из Баз данных, а те, в свою очередь, из схем (schema) — связанных по определенным ключам таблиц.
#
# Не запутаться во множестве связей между таблицами помогает визуализация их в виде специальной `диаграммы отношений или Entity Relationship `Diagram (ERD) — диаграммы связи сущностей.
#
# `Сущность (entity)` — это любой объект в базе данных, который может быть идентифицирован неким способом, отличающим его от других объектов. В нашем примере «сущность» — это пользователь и площадка.
#
# `Атрибут — свойство`, которое описывает некоторую характеристику объекта.
#
# `Пример:` рассмотрим множество пользователей системы бронирований. Каждого из них можно описать с помощью характеристик фамилия, имя, адрес и тд. Поэтому сущность member имеет атрибуты surname, firstname, address и тд.
#
# Таким образом, сущность фактически представляет из себя множество атрибутов, которые описывают свойства всех членов данного набора сущностей.
#
# ![image.png](attachment:image.png)
#
# Таблицы связаны между собой ключами, благодаря которым можно перемещаться между ними, подтягивая нужные данные.
#
# * `Первичный ключ (PRIMARY KEY)`–  идентифицирует каждую запись в таблице. Как правило, это уникальный идентификатор записи. Первичный ключ столбец не может иметь значения NULL. Таблица может иметь только один первичный ключ, который может состоять из одного или нескольких полей. Когда несколько полей используются в качестве первичного ключа, их называют составным ключом.
# * `Внешний ключ (FOREIGN KEY)` – устанавливает родительско-дочерние отношения в таблице. Обычно таблица с внешним ключом – дочерняя, а таблица без внешнего – родительская.
#
# ![image-2.png](attachment:image-2.png)
#
# `Транзакции` – операции обработки данных, которые переводят базу из одного состояния в другое.
#
# Транзакции подчиняются аббревиатуре ACID – атомарность, согласованность, изолированность и стойкость.
#
# `Атомарность` – гарантирует, что никакая транзакция не будет зафиксирована в системе частично
#
# `Согласованность` – каждая успешная транзакция по определению фиксирует только допустимые результаты.
#
# `Изолированность` – при параллельном выполнении транзакции никак не влияют друг на друга.
#
# `Стойкость` – если транзакция выполнена, то результат будет точно сохранен вне зависимости от проблем с оборудованием.

# %%
SELECT f.name, b.starttime, m.firstname, m.surname
FROM bookings b
JOIN facilities f on f.facid = b.facid
JOIN members m on b.memid = m.memid
WHERE firstname = 'David' AND DATE(b.starttime) > '2010-01-01';

# %% [markdown]
# # JOIN - объединяем таблицы
# Во всех примерах выше мы видели `id` у сущностей: у пользователя был `id`, у поста был `id`.
# Зачем они нужны?
#
# Для ответа на вопрос понадобится немного теории.
#
# ## Отношения
# PostgreSQL - _реляционная_ СУБД. Реляционный (англ. _relationalal_, "относительный") означает, что есть отношения между сущностями, хранящимися в базе данных. Например, могут быть отношения между пользователем и постом.
#
# Отношение - это некая взаимосвязь между сущностями. Обычно отношения задаются бизнес-требованиями и сутью лежащих в БД данных. Отношения порождают связи. `id` как раз выступают звеном в таких связях.
#
# ## JOIN
#  пример:

# %%
SELECT f.name, b.starttime
FROM bookings b                               # через пробел дали короткое имя b
JOIN facilities f on f.facid = b.facid;

# %% [markdown]
# В таблице `bookings` лежат id площадок и время бронирования.
# Чтобы забрать сам факультет, необходимо найти его по соответствию (`facid` в `bookings` <--> `facid` в `facilities`). Для этого мы воспользовались `JOIN`.
#
# `JOIN` пишется по следующим правилам:
# 1. Он должен идти после `FROM`.
# 2. Он должен выглядеть следующим образом: `JOIN иная_таблица ON условие_соединения`.
#
# Разбитие на две таблицы позволит не хранить в каждой записи таблицы `bookings` инофрмацию о площадке.
# Представьте себе ситуацию: одну и ту же площадку бронируют 1 млн раз. Если бы мы хранили всю информацию о площадке (название, стоимость и т.п.) в таблице бронирований, то получили бы 1 млн одинаковых значений в колонках. Много хранить, легко ошибиться. Использование `facid` и связки данных решило проблему: вместо дублирования длинной информации мы храним и дублируем короткое число - `facid`.

# %% [markdown]
# ## Несколько JOIN
# Можно соединять несколько таблиц в одном запросе:

# %%
SELECT f.name, b.starttime, m.firstname, m.surname
FROM bookings b
JOIN facilities f on f.facid = b.facid
JOIN members m on b.memid = m.memid
WHERE firstname = 'David' AND DATE(b.starttime) > '2010-01-01';

# %% [markdown]
# Этот запрос отдаст нам имя площадки, время брони, имя и фамилию забронировшего для всех записей, где бронировавшего зовут 'David' и дата брони больше 2010-01-01.
#
# _Обратите внимание_: мы воспользовались функцией в postgres. Это была функция `DATE(p.text)`, которая приняла на вход колонку `starttime` из таблицы `bookings` и вернула колонку с датой (отбросив время). Функции в postgres работают схожим с Python образом: тоже имеют аргументы и возвращаемое значение.

# %% [markdown]
# ## > Виды JOIN
#
# Когда мы склеиваем две таблички, не всегда может по `memid` в `bookings` найтись соответствующая запись в `members`. И наоборот: не для каждого `memid` из `members` может найтись запись в `bookings` с соответствующим `memid` (к примеру, если пользователь ничего не бронировал).
#
# SQL умеет обрабатывать эти случаи, и поддерживает несколько режимов.
#
# **Важное замечание**: если не писать, какой `JOIN`, то по умолчанию берется LEFT JOIN.

# %% [markdown]
# ### LEFT JOIN
# `LEFT JOIN` берет **все** данные из `FROM`, затем берутся **соответствующе** данные (не все!) в таблице после `JOIN`. Там, где нет результатов в таблице после `JOIN`, выставляет `NULL` (символ пропуска значения).
# ```sql
# SELECT f.name, b.starttime
# FROM bookings b
# LEFT JOIN facilities f on f.facid = b.facid;
# -- Берутся все bookings. Если для какого-нибудь bookings по facid не найдется площадка в facilities,
# -- то f.name будет заполнен NULL
# ```
#
# `LEFT JOIN` используется, когда важно сохранить все данные из оригинальной таблицы.
# **Важное замечание**: если не писать, какой `JOIN`, то по умолчанию берется LEFT JOIN.
# ### RIGHT JOIN
# Аналогичен LEFT JOIN, только теперь наоборот: сначала берутся **все** данные из таблицы в `RIGHT JOIN`, затем берутся **соответствующие** данные из таблицы в `FROM` (не все). Там, где нет соответствующих значений в таблице `FROM`, ставятся `NULL`:
# ```sql
# SELECT f.name, b.starttime
# FROM bookings b
# RIGHT JOIN facilities f on f.facid = b.facid;
# -- Берутся все площадки. Если для какого-нибудь facid из facilities не найдется facid в bookings,
# -- то b.starttime будет заполнен NULL.
# -- В любом случае будут возвращены все записи из facilites!
# ```
# `RIGHT JOIN` используется, когда важно получить данные из таблицы после `RIGHT JOIN`.
# `RIGHT JOIN` почти всегда можно свести к `LEFT JOIN`, поэтому выбирается обычно тот, что дает более читаемый код.
#
# ### INNER JOIN
# Комбинация LEFT JOIN и RIGHT JOIN, `INNER JOIN` выдаст в результате только пересечения обоих таблиц. Очень удобно, чтобы найти "хорошие" данные - те, где и там и тут сохранились записи.
#
# ```sql
# SELECT f.name, b.starttime
# FROM bookings b
# INNER JOIN facilities f on f.facid = b.facid;
# -- Возьмутся только те bookings, на которых найдется площадка в таблице facilities
# -- и только те площадки, на которые найдется хотя бы одна запись в bookings.
# -- Самый "узкий" из всех JOIN
# ```
# ### FULL OUTER JOIN
# Самый широкий JOIN. Берет все записи из обоих таблиц. Если нашлось соотвествие, то заполняет колонки, иначе помещает туда `NULL`.
# ```sql
# SELECT f.name, b.starttime
# FROM bookings b
# FULL OUTER JOIN facilities f on f.facid = b.facid;
# -- Возьмутся все записи из bookings и все записи из facilities.
# -- Там, где возможно установить соответствие, оно будет установлено.
# -- Где соответствие провести нельзя, будет помещен NULL,
# -- причем NULL может уйти как в таблицу слева, так и справа!
# -- Самый "широкий" из всех JOIN
# ```
#
# Наглядно различия между JOIN можно видеть на картинке ниже:
#
# ![Виды JOIN](https://www.codeproject.com/KB/database/Visual_SQL_Joins/Visual_SQL_JOINS_orig.jpg)

# %% [markdown]
# # SQL в Python
# ## psycopg2
# Для работы с SQL нам понадобится библиотека [psycopg2](https://pypi.org/project/psycopg2/). Она дает возможность подключаться к PostgreSQL и запускать SQL-запросы.

# %%
# !pip install psycopg2-binary

# %%
import psycopg2
# connection - это объект, который отвечает за соединение с БД
connection = psycopg2.connect(
    # database - это база данных (именно база, не СУБД)
    # PostgreSQL создает несколько баз данных
    # Каждая база данных содержит схемы (schema)
    # и каждая схема состоит из таблиц (тех, с кем мы уже работали)
    database='postgres',
    host='localhost',  # это говорит, что СУБД работает на моем компьютере
    user='postgres',  # имя пользователя
    password=''  # пароль
    # port=5432,  # порт не указываем, по умолчанию 5432
)
# cursor - это объект, который отвечает за воздействие с базой данных
cursor = connection.cursor()
# Делаем запрос
cursor.execute("""
SELECT * FROM lernsql1.address
""")
# Получаем результаты
results = cursor.fetchall()
results  # Это будет стандартный Python-объект. Не очень удобно, но работает
# Out:
# [(1,
#   '47 MySakila Drive',
#   300,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (2,
#   '28 MySQL Boulevard',
#   576,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (3,
#   '23 Workhaven Lane',
#   300,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (4,
#   '1411 Lillydale Drive',
#   576,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (5,
#   '1913 Hanoi Way',
#   463,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (6,
#   '1121 Loja Avenue',
#   449,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (7,
#   '692 Joliet Street',
#   38,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (8,
#   '1566 Inegl Manor',
#   349,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (9,
#   '53 Idfu Parkway',
#   361,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (10,
#   '1795 Santiago de Composte',
#   295,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (11,
#   '900 Santiago de Compostel',
#   280,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (12,
#   '478 Joliet Way',
#   200,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (13,
#   '613 Korolev Drive',
#   329,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (14,
#   '1531 Sal Drive',
#   162,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (15,
#   '1542 Tarlac Parkway',
#   440,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (16,
#   '808 Bhopal Manor',
#   582,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (17,
#   '270 Amroha Parkway',
#   384,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (18,
#   '770 Bydgoszcz Avenue',
#   120,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (19,
#   '419 Iligan Lane',
#   76,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (20,
#   '360 Toulouse Parkway',
#   495,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (21,
#   '270 Toulon Boulevard',
#   156,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (22,
#   '320 Brest Avenue',
#   252,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (23,
#   '1417 Lancaster Avenue',
#   267,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (24,
#   '1688 Okara Way',
#   327,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (25,
#   '262 A Corua (La Corua) Pa',
#   525,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (26,
#   '28 Charlotte Amalie Stree',
#   443,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (27,
#   '1780 Hino Boulevard',
#   303,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (28,
#   '96 Tafuna Way',
#   128,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (29,
#   '934 San Felipe de Puerto ',
#   472,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (30,
#   '18 Duisburg Boulevard',
#   121,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (31,
#   '217 Botshabelo Place',
#   138,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (32,
#   '1425 Shikarpur Manor',
#   346,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (33,
#   '786 Aurora Avenue',
#   474,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (34,
#   '1668 Anpolis Street',
#   316,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (35,
#   '33 Gorontalo Way',
#   257,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (36,
#   '176 Mandaluyong Place',
#   239,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (37,
#   '127 Purnea (Purnia) Manor',
#   17,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (38,
#   '61 Tama Street',
#   284,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (39,
#   '391 Callao Drive',
#   544,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (40,
#   '334 Munger (Monghyr) Lane',
#   31,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (41,
#   '1440 Fukuyama Loop',
#   362,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (42,
#   '269 Cam Ranh Parkway',
#   115,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (43,
#   '306 Antofagasta Place',
#   569,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (44,
#   '671 Graz Street',
#   353,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (45,
#   '42 Brindisi Place',
#   586,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (46,
#   '1632 Bislig Avenue',
#   394,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (47,
#   '1447 Imus Way',
#   167,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (48,
#   '1998 Halifax Drive',
#   308,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (49,
#   '1718 Valencia Street',
#   27,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (50,
#   '46 Pjatigorsk Lane',
#   343,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (51,
#   '686 Garland Manor',
#   247,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (52,
#   '909 Garland Manor',
#   367,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (53,
#   '725 Isesaki Place',
#   237,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (54,
#   '115 Hidalgo Parkway',
#   379,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (55,
#   '1135 Izumisano Parkway',
#   171,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (56,
#   '939 Probolinggo Loop',
#   1,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (57,
#   '17 Kabul Boulevard',
#   355,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (58,
#   '1964 Allappuzha (Alleppey',
#   227,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (59,
#   '1697 Kowloon and New Kowl',
#   49,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (60,
#   '1668 Saint Louis Place',
#   397,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (61,
#   '943 Tokat Street',
#   560,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (62,
#   '1114 Liepaja Street',
#   282,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (63,
#   '1213 Ranchi Parkway',
#   350,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (64,
#   '81 Hodeida Way',
#   231,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (65,
#   '915 Ponce Place',
#   56,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (66,
#   '1717 Guadalajara Lane',
#   441,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (67,
#   '1214 Hanoi Way',
#   306,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (68,
#   '1966 Amroha Avenue',
#   139,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (69,
#   '698 Otsu Street',
#   105,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (70,
#   '1150 Kimchon Manor',
#   321,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (71,
#   '1586 Guaruj Place',
#   579,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (72,
#   '57 Arlington Manor',
#   475,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (73,
#   '1031 Daugavpils Parkway',
#   63,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (74,
#   '1124 Buenaventura Drive',
#   13,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (75,
#   '492 Cam Ranh Street',
#   61,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (76,
#   '89 Allappuzha (Alleppey) ',
#   517,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (77,
#   '1947 Poos de Caldas Boule',
#   114,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (78,
#   '1206 Dos Quebradas Place',
#   431,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (79,
#   '1551 Rampur Lane',
#   108,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (80,
#   '602 Paarl Street',
#   402,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (81,
#   '1692 Ede Loop',
#   30,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (82,
#   '936 Salzburg Lane',
#   425,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (83,
#   '586 Tete Way',
#   256,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (84,
#   '1888 Kabul Drive',
#   217,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (85,
#   '320 Baiyin Parkway',
#   319,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (86,
#   '927 Baha Blanca Parkway',
#   479,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (87,
#   '929 Tallahassee Loop',
#   497,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (88,
#   '125 Citt del Vaticano Bou',
#   40,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (89,
#   '1557 Ktahya Boulevard',
#   88,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (90,
#   '870 Ashqelon Loop',
#   489,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (91,
#   '1740 Portoviejo Avenue',
#   480,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (92,
#   '1942 Ciparay Parkway',
#   113,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (93,
#   '1926 El Alto Avenue',
#   289,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (94,
#   '1952 Chatsworth Drive',
#   332,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (95,
#   '1370 Le Mans Avenue',
#   53,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (96,
#   '984 Effon-Alaiye Avenue',
#   183,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (97,
#   '832 Nakhon Sawan Manor',
#   592,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (98,
#   '152 Kitwe Parkway',
#   82,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (99,
#   '1697 Tanauan Lane',
#   399,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (100,
#   '1308 Arecibo Way',
#   41,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (101,
#   '1599 Plock Drive',
#   534,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (102,
#   '669 Firozabad Loop',
#   12,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (103,
#   '588 Vila Velha Manor',
#   268,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (104,
#   '1913 Kamakura Place',
#   238,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (105,
#   '733 Mandaluyong Place',
#   2,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (106,
#   '659 Vaduz Drive',
#   34,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (107,
#   '1177 Jelets Way',
#   220,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (108,
#   '1386 Yangor Avenue',
#   543,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (109,
#   '454 Nakhon Sawan Boulevar',
#   173,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (110,
#   '1867 San Juan Bautista Tu',
#   225,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (111,
#   '1532 Dzerzinsk Way',
#   334,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (112,
#   '1002 Ahmadnagar Manor',
#   213,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (113,
#   '682 Junan Way',
#   273,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (114,
#   '804 Elista Drive',
#   159,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (115,
#   '1378 Alvorada Avenue',
#   102,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (116,
#   '793 Cam Ranh Avenue',
#   292,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (117,
#   '1079 Tel Aviv-Jaffa Boule',
#   132,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (118,
#   '442 Rae Bareli Place',
#   148,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (119,
#   '1107 Nakhon Sawan Avenue',
#   365,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (120,
#   '544 Malm Parkway',
#   403,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (121,
#   '1967 Sincelejo Place',
#   176,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (122,
#   '333 Goinia Way',
#   185,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (123,
#   '1987 Coacalco de Berriozb',
#   476,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (124,
#   '241 Mosul Lane',
#   147,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (125,
#   '211 Chiayi Drive',
#   164,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (126,
#   '1175 Tanauan Way',
#   305,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (127,
#   '117 Boa Vista Way',
#   566,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (128,
#   '848 Tafuna Manor',
#   281,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (129,
#   '569 Baicheng Lane',
#   85,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (130,
#   '1666 Qomsheh Drive',
#   410,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (131,
#   '801 Hagonoy Drive',
#   484,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (132,
#   '1050 Garden Grove Avenue',
#   236,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (133,
#   '1854 Tieli Street',
#   302,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (134,
#   '758 Junan Lane',
#   190,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (135,
#   '1752 So Leopoldo Parkway',
#   345,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (136,
#   '898 Belm Manor',
#   87,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (137,
#   '261 Saint Louis Way',
#   541,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (138,
#   '765 Southampton Drive',
#   421,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (139,
#   '943 Johannesburg Avenue',
#   417,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (140,
#   '788 Atinsk Street',
#   211,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (141,
#   '1749 Daxian Place',
#   29,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (142,
#   '1587 Sullana Lane',
#   207,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (143,
#   '1029 Dzerzinsk Manor',
#   542,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (144,
#   '1666 Beni-Mellal Place',
#   123,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (145,
#   '928 Jaffna Loop',
#   172,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (146,
#   '483 Ljubertsy Parkway',
#   149,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (147,
#   '374 Bat Yam Boulevard',
#   266,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (148,
#   '1027 Songkhla Manor',
#   340,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (149,
#   '999 Sanaa Loop',
#   491,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (150,
#   '879 Newcastle Way',
#   499,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (151,
#   '1337 Lincoln Parkway',
#   555,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (152,
#   '1952 Pune Lane',
#   442,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (153,
#   '782 Mosul Street',
#   94,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (154,
#   '781 Shimonoseki Drive',
#   202,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (155,
#   '1560 Jelets Boulevard',
#   291,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (156,
#   '1963 Moscow Place',
#   354,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (157,
#   '456 Escobar Way',
#   232,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (158,
#   '798 Cianjur Avenue',
#   590,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (159,
#   '185 Novi Sad Place',
#   72,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (160,
#   '1367 Yantai Manor',
#   381,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (161,
#   '1386 Nakhon Sawan Bouleva',
#   420,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (162,
#   '369 Papeete Way',
#   187,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (163,
#   '1440 Compton Place',
#   307,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (164,
#   '1623 Baha Blanca Manor',
#   310,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (165,
#   '97 Shimoga Avenue',
#   533,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (166,
#   '1740 Le Mans Loop',
#   297,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (167,
#   '1287 Xiangfan Boulevard',
#   253,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (168,
#   '842 Salzburg Lane',
#   529,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (169,
#   '154 Tallahassee Loop',
#   199,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (170,
#   '710 San Felipe del Progre',
#   304,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (171,
#   '1540 Wroclaw Drive',
#   107,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (172,
#   '475 Atinsk Way',
#   240,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (173,
#   '1294 Firozabad Drive',
#   407,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (174,
#   '1877 Ezhou Lane',
#   550,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (175,
#   '316 Uruapan Street',
#   223,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (176,
#   '29 Pyongyang Loop',
#   58,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (177,
#   '1010 Klerksdorp Way',
#   186,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (178,
#   '1848 Salala Boulevard',
#   373,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (179,
#   '431 Xiangtan Avenue',
#   18,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (180,
#   '757 Rustenburg Avenue',
#   483,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (181,
#   '146 Johannesburg Way',
#   330,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (182,
#   '1891 Rizhao Boulevard',
#   456,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (183,
#   '1089 Iwatsuki Avenue',
#   270,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (184,
#   '1410 Benin City Parkway',
#   405,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (185,
#   '682 Garden Grove Place',
#   333,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (186,
#   '533 al-Ayn Boulevard',
#   126,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (187,
#   '1839 Szkesfehrvr Parkway',
#   317,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (188,
#   '741 Ambattur Manor',
#   438,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (189,
#   '927 Barcelona Street',
#   467,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (190,
#   '435 0 Way',
#   195,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (191,
#   '140 Chiayi Parkway',
#   506,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (192,
#   '1166 Changhwa Street',
#   62,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (193,
#   '891 Novi Sad Manor',
#   383,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (194,
#   '605 Rio Claro Parkway',
#   513,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (195,
#   '1077 San Felipe de Puerto',
#   369,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (196,
#   '9 San Miguel de Tucumn Ma',
#   169,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (197,
#   '447 Surakarta Loop',
#   271,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (198,
#   '345 Oshawa Boulevard',
#   204,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (199,
#   '1792 Valle de la Pascua P',
#   477,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (200,
#   '1074 Binzhou Manor',
#   325,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (201,
#   '817 Bradford Loop',
#   109,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (202,
#   '955 Bamenda Way',
#   218,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (203,
#   '1149 A Corua (La Corua) B',
#   194,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (204,
#   '387 Mwene-Ditu Drive',
#   35,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (205,
#   '68 Molodetno Manor',
#   575,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (206,
#   '642 Nador Drive',
#   77,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (207,
#   '1688 Nador Lane',
#   184,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (208,
#   '1215 Pyongyang Parkway',
#   557,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (209,
#   '1679 Antofagasta Street',
#   122,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (210,
#   '1304 s-Hertogenbosch Way',
#   83,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (211,
#   '850 Salala Loop',
#   371,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (212,
#   '624 Oshawa Boulevard',
#   51,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (213,
#   '43 Dadu Avenue',
#   74,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (214,
#   '751 Lima Loop',
#   7,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (215,
#   '1333 Haldia Street',
#   174,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (216,
#   '660 Jedda Boulevard',
#   65,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (217,
#   '1001 Miyakonojo Lane',
#   518,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (218,
#   '226 Brest Manor',
#   508,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (219,
#   '1229 Valencia Parkway',
#   498,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (220,
#   '1201 Qomsheh Manor',
#   28,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (221,
#   '866 Shivapuri Manor',
#   448,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (222,
#   '1168 Najafabad Parkway',
#   251,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (223,
#   '1244 Allappuzha (Alleppey',
#   567,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (224,
#   '1842 Luzinia Boulevard',
#   593,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (225,
#   '1926 Gingoog Street',
#   511,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (226,
#   '810 Palghat (Palakkad) Bo',
#   235,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (227,
#   '1820 Maring Parkway',
#   324,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (228,
#   '60 Poos de Caldas Street',
#   243,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (229,
#   '1014 Loja Manor',
#   22,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (230,
#   '201 Effon-Alaiye Way',
#   37,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (231,
#   '430 Alessandria Loop',
#   439,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (232,
#   '754 Valencia Place',
#   406,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (233,
#   '356 Olomouc Manor',
#   26,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (234,
#   '1256 Bislig Boulevard',
#   86,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (235,
#   '954 Kimchon Place',
#   559,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (236,
#   '885 Yingkou Manor',
#   596,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (237,
#   '1736 Cavite Place',
#   216,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (238,
#   '346 Skikda Parkway',
#   233,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (239,
#   '98 Stara Zagora Boulevard',
#   96,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (240,
#   '1479 Rustenburg Boulevard',
#   527,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (241,
#   '647 A Corua (La Corua) St',
#   357,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (242,
#   '1964 Gijn Manor',
#   473,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (243,
#   '47 Syktyvkar Lane',
#   118,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (244,
#   '1148 Saarbrcken Parkway',
#   226,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (245,
#   '1103 Bilbays Parkway',
#   578,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (246,
#   '1246 Boksburg Parkway',
#   422,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (247,
#   '1483 Pathankot Street',
#   454,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (248,
#   '582 Papeete Loop',
#   294,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (249,
#   '300 Junan Street',
#   553,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (250,
#   '829 Grand Prairie Way',
#   328,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (251,
#   '1473 Changhwa Parkway',
#   124,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (252,
#   '1309 Weifang Street',
#   520,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (253,
#   '1760 Oshawa Manor',
#   535,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (254,
#   '786 Stara Zagora Way',
#   390,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (255,
#   '1966 Tonghae Street',
#   198,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (256,
#   '1497 Yuzhou Drive',
#   312,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (257,
#   '752 Ondo Loop',
#   338,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (258,
#   '1338 Zalantun Lane',
#   413,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (259,
#   '127 Iwakuni Boulevard',
#   192,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (260,
#   '51 Laredo Avenue',
#   342,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (261,
#   '771 Yaound Manor',
#   64,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (262,
#   '532 Toulon Street',
#   460,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (263,
#   '1027 Banjul Place',
#   197,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (264,
#   '1158 Mandi Bahauddin Park',
#   136,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (265,
#   '862 Xintai Lane',
#   548,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (266,
#   '816 Cayenne Parkway',
#   414,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (267,
#   '1831 Nam Dinh Loop',
#   323,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (268,
#   '446 Kirovo-Tepetsk Lane',
#   203,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (269,
#   '682 Halisahar Place',
#   378,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (270,
#   '1587 Loja Manor',
#   447,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (271,
#   '1762 Paarl Parkway',
#   298,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (272,
#   '1519 Ilorin Place',
#   395,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (273,
#   '920 Kumbakonam Loop',
#   446,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (274,
#   '906 Goinia Way',
#   255,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (275,
#   '1675 Xiangfan Manor',
#   283,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (276,
#   '85 San Felipe de Puerto P',
#   584,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (277,
#   '144 South Hill Loop',
#   445,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (278,
#   '1884 Shikarpur Avenue',
#   263,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (279,
#   '1980 Kamjanets-Podilskyi ',
#   404,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (280,
#   '1944 Bamenda Way',
#   573,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (281,
#   '556 Baybay Manor',
#   374,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (282,
#   '457 Tongliao Loop',
#   222,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (283,
#   '600 Bradford Street',
#   514,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (284,
#   '1006 Santa Brbara dOeste ',
#   389,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (285,
#   '1308 Sumy Loop',
#   175,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (286,
#   '1405 Chisinau Place',
#   411,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (287,
#   '226 Halifax Street',
#   277,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (288,
#   '1279 Udine Parkway',
#   69,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (289,
#   '1336 Benin City Drive',
#   386,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (290,
#   '1155 Liaocheng Place',
#   152,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (291,
#   '1993 Tabuk Lane',
#   522,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (292,
#   '86 Higashiosaka Lane',
#   563,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (293,
#   '1912 Allende Manor',
#   279,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (294,
#   '544 Tarsus Boulevard',
#   562,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (295,
#   '1936 Cuman Avenue',
#   433,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (296,
#   '1192 Tongliao Street',
#   470,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (297,
#   '44 Najafabad Way',
#   146,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (298,
#   '32 Pudukkottai Lane',
#   140,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (299,
#   '661 Chisinau Lane',
#   274,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (300,
#   '951 Stara Zagora Manor',
#   400,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (301,
#   '922 Vila Velha Loop',
#   9,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (302,
#   '898 Jining Lane',
#   387,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (303,
#   '1635 Kuwana Boulevard',
#   205,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (304,
#   '41 El Alto Parkway',
#   398,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (305,
#   '1883 Maikop Lane',
#   254,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (306,
#   '1908 Gaziantep Place',
#   536,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (307,
#   '687 Alessandria Parkway',
#   455,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (308,
#   '827 Yuncheng Drive',
#   99,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (309,
#   '913 Coacalco de Berriozba',
#   33,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (310,
#   '715 So Bernardo do Campo ',
#   507,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (311,
#   '1354 Siegen Street',
#   25,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (312,
#   '1191 Sungai Petani Boulev',
#   262,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (313,
#   '1224 Huejutla de Reyes Bo',
#   91,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (314,
#   '543 Bergamo Avenue',
#   215,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (315,
#   '746 Joliet Lane',
#   286,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (316,
#   '780 Kimberley Way',
#   515,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (317,
#   '1774 Yaound Place',
#   166,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (318,
#   '1957 Yantai Lane',
#   490,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (319,
#   '1542 Lubumbashi Boulevard',
#   57,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (320,
#   '651 Pathankot Loop',
#   336,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (321,
#   '1359 Zhoushan Parkway',
#   545,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (322,
#   '1769 Iwaki Lane',
#   97,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (323,
#   '1145 Vilnius Manor',
#   451,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (324,
#   '1892 Nabereznyje Telny La',
#   516,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (325,
#   '470 Boksburg Street',
#   81,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (326,
#   '1427 A Corua (La Corua) P',
#   45,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (327,
#   '479 San Felipe del Progre',
#   130,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (328,
#   '867 Benin City Avenue',
#   591,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (329,
#   '981 Kumbakonam Place',
#   89,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (330,
#   '1016 Iwakuni Street',
#   269,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (331,
#   '663 Baha Blanca Parkway',
#   5,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (332,
#   '1860 Taguig Loop',
#   119,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (333,
#   '1816 Bydgoszcz Loop',
#   234,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (334,
#   '587 Benguela Manor',
#   42,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (335,
#   '430 Kumbakonam Drive',
#   457,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (336,
#   '1838 Tabriz Lane',
#   143,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (337,
#   '431 Szkesfehrvr Avenue',
#   48,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (338,
#   '503 Sogamoso Loop',
#   505,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (339,
#   '507 Smolensk Loop',
#   492,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (340,
#   '1920 Weifang Avenue',
#   427,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (341,
#   '124 al-Manama Way',
#   382,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (342,
#   '1443 Mardan Street',
#   392,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (343,
#   '1909 Benguela Lane',
#   581,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (344,
#   '68 Ponce Parkway',
#   201,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (345,
#   '1217 Konotop Avenue',
#   151,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (346,
#   '1293 Nam Dinh Way',
#   84,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (347,
#   '785 Vaduz Street',
#   335,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (348,
#   '1516 Escobar Drive',
#   370,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (349,
#   '1628 Nagareyama Lane',
#   453,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (350,
#   '1157 Nyeri Loop',
#   320,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (351,
#   '1673 Tangail Drive',
#   137,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (352,
#   '381 Kabul Way',
#   209,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (353,
#   '953 Hodeida Street',
#   221,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (354,
#   '469 Nakhon Sawan Street',
#   531,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (355,
#   '1378 Beira Loop',
#   597,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (356,
#   '1641 Changhwa Place',
#   52,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (357,
#   '1698 Southport Loop',
#   393,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (358,
#   '519 Nyeri Manor',
#   461,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (359,
#   '619 Hunuco Avenue',
#   331,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (360,
#   '45 Aparecida de Goinia Pl',
#   464,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (361,
#   '482 Kowloon and New Kowlo',
#   90,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (362,
#   '604 Bern Place',
#   429,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (363,
#   '1623 Kingstown Drive',
#   20,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (364,
#   '1009 Zanzibar Lane',
#   32,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (365,
#   '114 Jalib al-Shuyukh Mano',
#   585,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (366,
#   '1163 London Parkway',
#   66,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (367,
#   '1658 Jastrzebie-Zdrj Loop',
#   372,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (368,
#   '817 Laredo Avenue',
#   188,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (369,
#   '1565 Tangail Manor',
#   377,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (370,
#   '1912 Emeishan Drive',
#   50,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (371,
#   '230 Urawa Drive',
#   8,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (372,
#   '1922 Miraj Way',
#   356,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (373,
#   '433 Florencia Street',
#   250,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (374,
#   '1049 Matamoros Parkway',
#   191,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (375,
#   '1061 Ede Avenue',
#   98,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (376,
#   '154 Oshawa Manor',
#   415,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (377,
#   '1191 Tandil Drive',
#   523,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (378,
#   '1133 Rizhao Avenue',
#   572,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (379,
#   '1519 Santiago de los Caba',
#   348,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (380,
#   '1618 Olomouc Manor',
#   285,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (381,
#   '220 Hidalgo Drive',
#   265,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (382,
#   '686 Donostia-San Sebastin',
#   471,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (383,
#   '97 Mogiljov Lane',
#   73,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (384,
#   '1642 Charlotte Amalie Dri',
#   549,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (385,
#   '1368 Maracabo Boulevard',
#   493,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (386,
#   '401 Sucre Boulevard',
#   322,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (387,
#   '368 Hunuco Boulevard',
#   360,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (388,
#   '500 Lincoln Parkway',
#   210,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (389,
#   '102 Chapra Drive',
#   521,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (390,
#   '1793 Meixian Place',
#   258,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (391,
#   '514 Ife Way',
#   315,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (392,
#   '717 Changzhou Lane',
#   104,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (393,
#   '753 Ilorin Avenue',
#   157,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (394,
#   '1337 Mit Ghamr Avenue',
#   358,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (395,
#   '767 Pyongyang Drive',
#   229,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (396,
#   '614 Pak Kret Street',
#   6,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (397,
#   '954 Lapu-Lapu Way',
#   278,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (398,
#   '331 Bydgoszcz Parkway',
#   181,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (399,
#   '1152 Citrus Heights Manor',
#   15,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (400,
#   '168 Cianjur Manor',
#   228,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (401,
#   '616 Hagonoy Avenue',
#   39,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (402,
#   '1190 0 Place',
#   44,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (403,
#   '734 Bchar Place',
#   375,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (404,
#   '530 Lausanne Lane',
#   135,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (405,
#   '454 Patiala Lane',
#   276,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (406,
#   '1346 Mysore Drive',
#   92,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (407,
#   '990 Etawah Loop',
#   564,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (408,
#   '1266 Laredo Parkway',
#   380,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (409,
#   '88 Nagaon Manor',
#   524,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (410,
#   '264 Bhimavaram Manor',
#   111,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (411,
#   '1639 Saarbrcken Drive',
#   437,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (412,
#   '692 Amroha Drive',
#   230,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (413,
#   '1936 Lapu-Lapu Parkway',
#   141,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (414,
#   '432 Garden Grove Street',
#   430,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (415,
#   '1445 Carmen Parkway',
#   117,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (416,
#   '791 Salinas Street',
#   208,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (417,
#   '126 Acua Parkway',
#   71,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (418,
#   '397 Sunnyvale Avenue',
#   19,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (419,
#   '992 Klerksdorp Loop',
#   23,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (420,
#   '966 Arecibo Loop',
#   134,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (421,
#   '289 Santo Andr Manor',
#   16,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (422,
#   '437 Chungho Drive',
#   450,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (423,
#   '1948 Bayugan Parkway',
#   264,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (424,
#   '1866 al-Qatif Avenue',
#   155,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (425,
#   '1661 Abha Drive',
#   416,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (426,
#   '1557 Cape Coral Parkway',
#   293,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (427,
#   '1727 Matamoros Place',
#   465,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (428,
#   '1269 Botosani Manor',
#   468,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (429,
#   '355 Vitria de Santo Anto ',
#   452,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (430,
#   '1596 Acua Parkway',
#   418,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (431,
#   '259 Ipoh Drive',
#   189,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (432,
#   '1823 Hoshiarpur Lane',
#   510,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (433,
#   '1404 Taguig Drive',
#   547,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (434,
#   '740 Udaipur Lane',
#   150,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (435,
#   '287 Cuautla Boulevard',
#   501,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (436,
#   '1766 Almirante Brown Stre',
#   364,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (437,
#   '596 Huixquilucan Place',
#   351,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (438,
#   '1351 Aparecida de Goinia ',
#   391,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (439,
#   '722 Bradford Lane',
#   249,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (440,
#   '983 Santa F Way',
#   565,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (441,
#   '1245 Ibirit Way',
#   290,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (442,
#   '1836 Korla Parkway',
#   272,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (443,
#   '231 Kaliningrad Place',
#   70,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (444,
#   '495 Bhimavaram Lane',
#   144,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (445,
#   '1924 Shimonoseki Drive',
#   59,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (446,
#   '105 Dzerzinsk Manor',
#   540,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (447,
#   '614 Denizli Parkway',
#   486,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (448,
#   '1289 Belm Boulevard',
#   530,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (449,
#   '203 Tambaram Street',
#   161,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (450,
#   '1704 Tambaram Manor',
#   554,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (451,
#   '207 Cuernavaca Loop',
#   352,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (452,
#   '319 Springs Loop',
#   160,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (453,
#   '956 Nam Dinh Manor',
#   481,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (454,
#   '1947 Paarl Way',
#   509,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (455,
#   '814 Simferopol Loop',
#   154,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (456,
#   '535 Ahmadnagar Manor',
#   3,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (457,
#   '138 Caracas Boulevard',
#   326,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (458,
#   '251 Florencia Drive',
#   556,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (459,
#   '659 Gatineau Boulevard',
#   153,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (460,
#   '1485 Bratislava Place',
#   435,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (461,
#   '935 Aden Boulevard',
#   532,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (462,
#   '76 Kermanshah Manor',
#   423,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (463,
#   '734 Tanshui Avenue',
#   170,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (464,
#   '118 Jaffna Loop',
#   182,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (465,
#   '1621 Tongliao Avenue',
#   558,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (466,
#   '1844 Usak Avenue',
#   196,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (467,
#   '1872 Toulon Loop',
#   428,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (468,
#   '1088 Ibirit Place',
#   595,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (469,
#   '1322 Mosul Parkway',
#   145,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (470,
#   '1447 Chatsworth Place',
#   129,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (471,
#   '1257 Guadalajara Street',
#   78,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (472,
#   '1469 Plock Lane',
#   388,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (473,
#   '434 Ourense (Orense) Mano',
#   206,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (474,
#   '270 Tambaram Parkway',
#   244,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (475,
#   '1786 Salinas Place',
#   359,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (476,
#   '1078 Stara Zagora Drive',
#   301,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (477,
#   '1854 Okara Boulevard',
#   158,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (478,
#   '421 Yaound Street',
#   385,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (479,
#   '1153 Allende Way',
#   179,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (480,
#   '808 Naala-Porto Parkway',
#   500,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (481,
#   '632 Usolje-Sibirskoje Par',
#   36,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (482,
#   '98 Pyongyang Boulevard',
#   11,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (483,
#   '984 Novoterkassk Loop',
#   180,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (484,
#   '64 Korla Street',
#   347,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (485,
#   '1785 So Bernardo do Campo',
#   125,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (486,
#   '698 Jelets Boulevard',
#   142,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (487,
#   '1297 Alvorada Parkway',
#   587,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (488,
#   '1909 Dayton Avenue',
#   469,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (489,
#   '1789 Saint-Denis Parkway',
#   4,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (490,
#   '185 Mannheim Lane',
#   408,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (491,
#   '184 Mandaluyong Street',
#   288,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (492,
#   '591 Sungai Petani Drive',
#   376,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (493,
#   '656 Matamoros Drive',
#   487,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (494,
#   '775 ostka Drive',
#   337,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (495,
#   '1013 Tabuk Boulevard',
#   261,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (496,
#   '319 Plock Parkway',
#   504,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (497,
#   '1954 Kowloon and New Kowl',
#   434,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (498,
#   '362 Rajkot Lane',
#   47,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (499,
#   '1060 Tandil Lane',
#   432,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (500,
#   '1515 Korla Way',
#   589,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (501,
#   '1416 San Juan Bautista Tu',
#   444,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (502,
#   '1 Valle de Santiago Avenu',
#   93,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (503,
#   '519 Brescia Parkway',
#   318,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (504,
#   '414 Mandaluyong Street',
#   314,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (505,
#   '1197 Sokoto Boulevard',
#   478,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (506,
#   '496 Celaya Drive',
#   552,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (507,
#   '786 Matsue Way',
#   245,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (508,
#   '48 Maracabo Place',
#   519,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (509,
#   '1152 al-Qatif Lane',
#   412,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (510,
#   '1269 Ipoh Avenue',
#   163,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (511,
#   '758 Korolev Parkway',
#   568,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (512,
#   '1747 Rustenburg Place',
#   110,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (513,
#   '886 Tonghae Place',
#   259,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (514,
#   '1574 Goinia Boulevard',
#   502,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (515,
#   '548 Uruapan Street',
#   312,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (516,
#   '962 Tama Loop',
#   583,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (517,
#   '1778 Gijn Manor',
#   594,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (518,
#   '568 Dhule (Dhulia) Loop',
#   127,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (519,
#   '1768 Udine Loop',
#   60,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (520,
#   '608 Birgunj Parkway',
#   116,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (521,
#   '680 A Corua (La Corua) Ma',
#   482,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (522,
#   '1949 Sanya Street',
#   224,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (523,
#   '617 Klerksdorp Place',
#   366,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (524,
#   '1993 0 Loop',
#   588,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (525,
#   '1176 Southend-on-Sea Mano',
#   458,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (526,
#   '600 Purnea (Purnia) Avenu',
#   571,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (527,
#   '1003 Qinhuangdao Street',
#   419,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (528,
#   '1986 Sivas Place',
#   551,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (529,
#   '1427 Tabuk Place',
#   101,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (530,
#   '556 Asuncin Way',
#   339,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (531,
#   '486 Ondo Parkway',
#   67,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (532,
#   '635 Brest Manor',
#   75,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (533,
#   '166 Jinchang Street',
#   165,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (534,
#   '958 Sagamihara Lane',
#   287,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (535,
#   '1817 Livorno Way',
#   100,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (536,
#   '1332 Gaziantep Lane',
#   80,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (537,
#   '949 Allende Lane',
#   24,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (538,
#   '195 Ilorin Street',
#   363,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (539,
#   '193 Bhusawal Place',
#   539,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (540,
#   '43 Vilnius Manor',
#   42,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (541,
#   '183 Haiphong Street',
#   46,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (542,
#   '163 Augusta-Richmond Coun',
#   561,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (543,
#   '191 Jos Azueta Parkway',
#   436,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (544,
#   '379 Lublin Parkway',
#   309,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (545,
#   '1658 Cuman Loop',
#   396,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (546,
#   '454 Qinhuangdao Drive',
#   68,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (547,
#   '1715 Okayama Street',
#   485,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (548,
#   '182 Nukualofa Drive',
#   275,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (549,
#   '390 Wroclaw Way',
#   462,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (550,
#   '1421 Quilmes Lane',
#   260,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (551,
#   '947 Trshavn Place',
#   528,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (552,
#   '1764 Jalib al-Shuyukh Par',
#   459,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (553,
#   '346 Cam Ranh Avenue',
#   599,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (554,
#   '1407 Pachuca de Soto Plac',
#   21,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (555,
#   '904 Clarksville Drive',
#   193,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (556,
#   '1917 Kumbakonam Parkway',
#   368,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (557,
#   '1447 Imus Place',
#   426,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (558,
#   '1497 Fengshan Drive',
#   112,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (559,
#   '869 Shikarpur Way',
#   496,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (560,
#   '1059 Yuncheng Avenue',
#   570,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (561,
#   '505 Madiun Boulevard',
#   577,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (562,
#   '1741 Hoshiarpur Boulevard',
#   79,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (563,
#   '1229 Varanasi (Benares) M',
#   43,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (564,
#   '1894 Boa Vista Way',
#   178,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (565,
#   '1342 Sharja Way',
#   488,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (566,
#   '1342 Abha Boulevard',
#   95,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (567,
#   '415 Pune Avenue',
#   580,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (568,
#   '1746 Faaa Way',
#   214,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (569,
#   '539 Hami Way',
#   538,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (570,
#   '1407 Surakarta Manor',
#   466,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (571,
#   '502 Mandi Bahauddin Parkw',
#   55,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (572,
#   '1052 Pathankot Avenue',
#   299,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (573,
#   '1351 Sousse Lane',
#   341,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (574,
#   '1501 Pangkal Pinang Avenu',
#   409,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (575,
#   '1405 Hagonoy Avenue',
#   133,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (576,
#   '521 San Juan Bautista Tux',
#   598,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (577,
#   '923 Tangail Boulevard',
#   10,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (578,
#   '186 Skikda Lane',
#   131,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (579,
#   '1568 Celaya Parkway',
#   168,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (580,
#   '1489 Kakamigahara Lane',
#   526,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (581,
#   '1819 Alessandria Loop',
#   103,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (582,
#   '1208 Tama Loop',
#   344,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (583,
#   '951 Springs Lane',
#   219,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (584,
#   '760 Miyakonojo Drive',
#   246,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (585,
#   '966 Asuncin Way',
#   212,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (586,
#   '1584 Ljubertsy Lane',
#   494,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (587,
#   '247 Jining Parkway',
#   54,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (588,
#   '773 Dallas Manor',
#   424,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (589,
#   '1923 Stara Zagora Lane',
#   546,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (590,
#   '1402 Zanzibar Boulevard',
#   106,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (591,
#   '1464 Kursk Parkway',
#   574,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (592,
#   '1074 Sanaa Parkway',
#   311,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (593,
#   '1759 Niznekamsk Avenue',
#   14,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (594,
#   '32 Liaocheng Way',
#   248,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (595,
#   '42 Fontana Avenue',
#   512,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (596,
#   '1895 Zhezqazghan Drive',
#   177,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (597,
#   '1837 Kaduna Parkway',
#   241,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (598,
#   '844 Bucuresti Place',
#   242,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (599,
#   '1101 Bucuresti Boulevard',
#   401,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (600,
#   '1103 Quilmes Boulevard',
#   503,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (601,
#   '1331 Usak Boulevard',
#   296,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False),
#  (602,
#   '1325 Fukuyama Street',
#   537,
#   datetime.datetime(2021, 10, 14, 18, 19, 57, 588936),
#   False)]

# %%
import pandas as pd

# второй аргумент будет специальная строка. Для PostgreSQL имеет вид:
# postgresql://имя:пароль@хост:порт/база_данных

conn_uri = "postgresql://postgres:@localhost:5432/postgres"

df = pd.read_sql(
    # первый аргумент - SQL запрос
    """
    SELECT * 
    FROM lernsql1.address a 
    join lernsql1.customer c on a.address_id = c.address_id
    WHERE c.deleted = 'False'
    """, 
    conn_uri  # наша строка с подключением
)
df_aggregate = df.copy()
df.head()
# Out:
#    address_id                    address  city_id               created_date  \
# 0           7          692 Joliet Street       38 2021-10-14 18:19:57.588936
# 1          10  1795 Santiago de Composte      295 2021-10-14 18:19:57.588936
# 2          12             478 Joliet Way      200 2021-10-14 18:19:57.588936
# 3          14             1531 Sal Drive      162 2021-10-14 18:19:57.588936
# 4          15        1542 Tarlac Parkway      440 2021-10-14 18:19:57.588936
#
#    deleted  customer_id last_name first_name  \
# 0    False            1  Williams      Linda
# 1    False            2     Davis   Jennifer
# 2    False            3    Wilson      Susan
# 3    False            4    Taylor    Dorothy
# 4    False            5  Anderson       Lisa
#
#                                email   password  address_id   born_date  \
# 0  linda.williams@sakilacustomer.org  321152459           7  1954-10-12
# 1  jennifer.davis@sakilacustomer.org  523065559          10  1976-01-07
# 2    susan.wilson@sakilacustomer.org  520707267          12  1967-05-27
# 3  dorothy.taylor@sakilacustomer.org  383883532          14  1955-01-24
# 4   lisa.anderson@sakilacustomer.org  739726872          15  1964-12-08
#
#                 created_date  deleted
# 0 2021-10-14 18:23:09.828876    False
# 1 2021-10-14 18:23:09.828876    False
# 2 2021-10-14 18:23:09.828876    False
# 3 2021-10-14 18:23:09.828876    False
# 4 2021-10-14 18:23:09.828876    False

# %% [markdown]
# ### Запись
# `pandas` умеет не только читать таблицу, но и записывать данные обратно! Для этого используется функция `to_sql`:

# %%
# и сохраним эти данные в БД
df_aggregate.to_sql(
    # имя таблицы, куда писать данные
    "agg_customer",
    # строка для подключения к БД
    conn_uri,
    # Схема, в которой создать таблицу
    schema="lernsql1",
    # что делать, если уже существует. Одно из трех значений
    # 'fail' - выдать ошибку
    # 'replace' - снести и создать с новыми данными
    # 'append' - дополнить датафреймом, не трогая существующие данные
    if_exists='replace'
)
# Out:
# 389

# %%
# читаем успешно записанную табличку
import pandas as pd

# второй аргумент будет специальная строка. Для PostgreSQL имеет вид:
# postgresql://имя:пароль@хост:порт/база_данных

conn_uri = "postgresql://postgres:@localhost:5432/postgres"

df = pd.read_sql(
    # первый аргумент - SQL запрос
    """
    SELECT * 
    FROM lernsql1.agg_customer
    """, 
    conn_uri  # наша строка с подключением
)
df.head()
# Out:
#    index  address_id                    address  city_id  \
# 0      0           7          692 Joliet Street       38
# 1      1          10  1795 Santiago de Composte      295
# 2      2          12             478 Joliet Way      200
# 3      3          14             1531 Sal Drive      162
# 4      4          15        1542 Tarlac Parkway      440
#
#                 created_date  deleted  customer_id last_name first_name  \
# 0 2021-10-14 18:23:09.828876    False            1  Williams      Linda
# 1 2021-10-14 18:23:09.828876    False            2     Davis   Jennifer
# 2 2021-10-14 18:23:09.828876    False            3    Wilson      Susan
# 3 2021-10-14 18:23:09.828876    False            4    Taylor    Dorothy
# 4 2021-10-14 18:23:09.828876    False            5  Anderson       Lisa
#
#                                email   password   born_date
# 0  linda.williams@sakilacustomer.org  321152459  1954-10-12
# 1  jennifer.davis@sakilacustomer.org  523065559  1976-01-07
# 2    susan.wilson@sakilacustomer.org  520707267  1967-05-27
# 3  dorothy.taylor@sakilacustomer.org  383883532  1955-01-24
# 4   lisa.anderson@sakilacustomer.org  739726872  1964-12-08

# %%
df.groupby('city_id')['address_id'].count().value_counts()
# Out:
# 312    2
# 42     2
# 38     1
# 358    1
# 44     1
#       ..
# 506    1
# 195    1
# 467    1
# 126    1
# 296    1
# Name: city_id, Length: 387, dtype: int64
